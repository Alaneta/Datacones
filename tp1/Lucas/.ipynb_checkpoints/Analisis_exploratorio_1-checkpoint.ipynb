# %%
import csv
import pandas as pd
import numpy as np
from datetime import datetime

import matplotlib as mp

# %matplotlib inline
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', '{:.2f}'.format)

train = pd.read_csv('../data/train.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# lng                           116512 non-null float64
# fecha                         240000 non-null object
# gimnasio                      240000 non-null float64
# usosmultiples                 240000 non-null float64
# piscina                       240000 non-null float64
# escuelascercanas              240000 non-null float64
# centroscomercialescercanos    240000 non-null float64
# precio                        240000 non-null float64
# dtypes: float64(15), int64(1), object(7)
# memory usage: 42.1+ MB

# %%
train.dtypes
# Out:
# id                              int64
# titulo                         object
# descripcion                    object
# tipodepropiedad                object
# direccion                      object
# ciudad                         object
# provincia                      object
# antiguedad                    float64
# habitaciones                  float64
# garages                       float64
# banos                         float64
# metroscubiertos               float64
# metrostotales                 float64
# idzona                        float64
# lat                           float64
# lng                           float64
# fecha                          object
# gimnasio                      float64
# usosmultiples                 float64
# piscina                       float64
# escuelascercanas              float64
# centroscomercialescercanos    float64
# precio                        float64
# dtype: object

# %%
train.describe()
# Out:
#              id  antiguedad  habitaciones   garages     banos  \
# count 240000.00   196445.00     217529.00 202235.00 213779.00
# mean  149969.38        8.12          2.90      1.55      2.13
# std    86634.58        9.55          0.90      0.85      0.91
# min        1.00        0.00          1.00      0.00      1.00
# 25%    74930.75        0.00          2.00      1.00      1.00
# 50%   149875.50        5.00          3.00      2.00      2.00
# 75%   225016.50       10.00          3.00      2.00      3.00
# max   299999.00       80.00         10.00      3.00      4.00
#
#        metroscubiertos  metrostotales      idzona       lat       lng  \
# count        222600.00      188533.00   211379.00 116512.00 116512.00
# mean            174.02         176.77  2423467.82     20.70    -99.51
# std              98.15          94.43 10567938.36      3.14      9.74
# min              15.00          15.00       22.00   -100.89   -125.86
# 25%              90.00         102.00    24890.00     19.36   -100.98
# 50%             153.00         155.00    56383.00     19.54    -99.24
# 75%             240.00         238.00    87838.00     20.74    -99.13
# max             439.00         439.00 50003999.00     83.03    121.04
#
#        gimnasio  usosmultiples   piscina  escuelascercanas  \
# count 240000.00      240000.00 240000.00         240000.00
# mean       0.06           0.06      0.09              0.44
# std        0.24           0.23      0.28              0.50
# min        0.00           0.00      0.00              0.00
# 25%        0.00           0.00      0.00              0.00
# 50%        0.00           0.00      0.00              0.00
# 75%        0.00           0.00      0.00              1.00
# max        1.00           1.00      1.00              1.00
#
#        centroscomercialescercanos      precio
# count                   240000.00   240000.00
# mean                         0.40  2530838.35
# std                          0.49  2152551.80
# min                          0.00   310000.00
# 25%                          0.00   952772.50
# 50%                          0.00  1850000.00
# 75%                          1.00  3390000.00
# max                          1.00 12525000.00

# %%
#Transformamos las fechas
train['fecha'] = pd.to_datetime(train['fecha'])

# %%
train.dtypes
# Out:
# id                                     int64
# titulo                                object
# descripcion                           object
# tipodepropiedad                       object
# direccion                             object
# ciudad                                object
# provincia                             object
# antiguedad                           float64
# habitaciones                         float64
# garages                              float64
# banos                                float64
# metroscubiertos                      float64
# metrostotales                        float64
# idzona                               float64
# lat                                  float64
# lng                                  float64
# fecha                         datetime64[ns]
# gimnasio                             float64
# usosmultiples                        float64
# piscina                              float64
# escuelascercanas                     float64
# centroscomercialescercanos           float64
# precio                               float64
# dtype: object

# %%
train['garages'].head(10)
# Out:
# 0   1.00
# 1   2.00
# 2   2.00
# 3   1.00
# 4   1.00
# 5   1.00
# 6   1.00
# 7   2.00
# 8   1.00
# 9    nan
# Name: garages, dtype: float64

# %%
#Con fillna seteamos los valores de 'garages' nan en '0'.
train['garages'].fillna(0,inplace=True)
train['garages'].head(10)
# Out:
# 0   1.00
# 1   2.00
# 2   2.00
# 3   1.00
# 4   1.00
# 5   1.00
# 6   1.00
# 7   2.00
# 8   1.00
# 9   0.00
# Name: garages, dtype: float64

# %%
train['banos'].head(10)
# Out:
# 0   2.00
# 1   2.00
# 2   2.00
# 3   1.00
# 4   1.00
# 5   1.00
# 6   2.00
# 7   3.00
# 8   1.00
# 9    nan
# Name: banos, dtype: float64

# %%
# Filtramos los banos según sea casa ó terreno
#train['count'] = 1
#train[train['banos'].isnull()][['banos','count','tipodepropiedad']]
#train[train['tipodepropiedad'] == 'Terreno'][['banos','count']].count()

#train[train['tipodepropiedad'] == 'Terreno']['banos'].fillna(0,inplace=True)

#train[train['tipodepropiedad'] == 'Terreno'][['banos','count']].count()

# %%
# Seteamos los banos Nan en '1'; ya que es dificil que una casa

# %%
train_filtrado = pd.DataFrame()
train_filtrado = train
train_filtrado.describe()
# Out:
#              id  antiguedad  habitaciones   garages     banos  \
# count 240000.00   196445.00     217529.00 240000.00 213779.00
# mean  149969.38        8.12          2.90      1.30      2.13
# std    86634.58        9.55          0.90      0.96      0.91
# min        1.00        0.00          1.00      0.00      1.00
# 25%    74930.75        0.00          2.00      0.00      1.00
# 50%   149875.50        5.00          3.00      1.00      2.00
# 75%   225016.50       10.00          3.00      2.00      3.00
# max   299999.00       80.00         10.00      3.00      4.00
#
#        metroscubiertos  metrostotales      idzona       lat       lng  \
# count        222600.00      188533.00   211379.00 116512.00 116512.00
# mean            174.02         176.77  2423467.82     20.70    -99.51
# std              98.15          94.43 10567938.36      3.14      9.74
# min              15.00          15.00       22.00   -100.89   -125.86
# 25%              90.00         102.00    24890.00     19.36   -100.98
# 50%             153.00         155.00    56383.00     19.54    -99.24
# 75%             240.00         238.00    87838.00     20.74    -99.13
# max             439.00         439.00 50003999.00     83.03    121.04
#
#        gimnasio  usosmultiples   piscina  escuelascercanas  \
# count 240000.00      240000.00 240000.00         240000.00
# mean       0.06           0.06      0.09              0.44
# std        0.24           0.23      0.28              0.50
# min        0.00           0.00      0.00              0.00
# 25%        0.00           0.00      0.00              0.00
# 50%        0.00           0.00      0.00              0.00
# 75%        0.00           0.00      0.00              1.00
# max        1.00           1.00      1.00              1.00
#
#        centroscomercialescercanos      precio
# count                   240000.00   240000.00
# mean                         0.40  2530838.35
# std                          0.49  2152551.80
# min                          0.00   310000.00
# 25%                          0.00   952772.50
# 50%                          0.00  1850000.00
# 75%                          1.00  3390000.00
# max                          1.00 12525000.00

# %%
# Removemos los nulls y Nan
#for prop in train_filtrado.columns:
#    str_prop = str(prop)
#    if (prop != 'idzona') & (prop != 'lat') & (prop != 'lng') & (prop != 'direccion')\
#        & (prop != 'titulo') & (prop != 'descripcion'):
#        print(str_prop+" count null antes: "+str(train_filtrado[train_filtrado[str_prop].isnull()]['id'].count()))
#        train_filtrado = train_filtrado.loc[(~train_filtrado[str_prop].isnull())]
#        print(str_prop+" count null despues: "+str(train_filtrado[train_filtrado[str_prop].isnull()]['id'].count()))
#        print("--------------------")

# %%
train_filtrado.describe
# Out:
# <bound method NDFrame.describe of             id                                             titulo  \
# 0       254099                                  depto. tipo a-402
#
id:19816, muy bonito e iluminado departamento,...         Apartamento
#
#                                                 direccion  \
# 0                         Avenida Division del Norte 2005
# 1                                              AV. MEXICO
# 2                                             Urbi Tonala
# 3                           IGNACIO MANUEL ALTAMIRANO 128
# 4                                         PASEOS DEL SOL
# 5                                   Condominio Tlalpan 2B
# 6                                                     NaN
# 7                                    condominio el trebol
# 8                          BUENAVISTA DEPTOS CON SUBSIDIO
# 9                                             Av. Morelos
# 10                                          MI 2° CREDITO
# 11                                                    NaN
# 12                               Pitahayas 2 - 58, Zibata
# 13                       MATIAS ROMERO, COLONIA DEL VALLE
# 14                                                    NaN
# 15                                                    NaN
# 16         CUMBRES DEL LAGO JURIQUILLA, QUERETARO, MEXICO
# 17                                      Pazaje Santa Cruz
# 18                                                Milenio
# 19                                     SENDA CELESTIAL 10
# 20               TERRENO RESIDENCIAL EN VENTA EN CUMBRES
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                           Colinas del Cimatario   C721
# 25                                          Lopez Velarde
# 26                              MISIONES DE SAN FRANCISCO
# 27                                  PASEO DE LOS LAURELES
# 28                             Coto Santillana I Casa G11
# 29                                camino viejo a Tesistan
# ...                                                   ...
# 239970                       Paseo de los fambruesos 3150
# 239971                                              TOKIO
# 239972                                  Albino Garcia 219
# 239973                                  Pérez de León  61
# 239974                                                NaN
# 239975                                                NaN
# 239976                                                NaN
# 239977                                    AV RANCHO NUEVO
# 239978                                                NaN
# 239979                                         Rio Parana
# 239980                                                NaN
# 239981                                      PRIV. VENECIA
# 239982                                                NaN
# 239983                                                NaN
# 239984                                PROGRESO, MONTERREY
# 239985    FUENTES DE SATÉLITE, ATIZAPÁN, ESTADO DE MÉXICO
# 239986                                                NaN
# 239987                                  Primero de mayo 5
# 239988                                       SANTA MARIA
# 239989                                             Jurica
# 239990                                                NaN
# 239991                                         Coyuya 200
# 239992                            Cerrada villa Picadilly
# 239993                                 Paseo de la Cañada
# 239994  MANUEL AMAYA,ENTRE SEBASTIAN ALLENDE Y AMADO A...
# 239995                                            BOSQUES
# 239996                                Filiberto Navas 325
# 239997                                   Nicolas San Juan
# 239998                              Javier Rojo Gomez 120
# 239999                                          AVE. STIM
#
#                         ciudad              provincia  antiguedad  \
# 0                Benito Juárez       Distrito Federal         nan
# 1       La Magdalena Contreras       Distrito Federal       10.00
# 2                       Tonalá                Jalisco        5.00
# 3                 Zinacantepec         Edo. de México        1.00
# 4                      Zapopan                Jalisco       10.00
# 5                     Coyoacán       Distrito Federal        5.00
# 6             Oaxaca de Juárez                 Oaxaca         nan
# 7             Playa del Carmen           Quintana Roo        2.00
# 8             Villa de Alvarez                 Colima        1.00
# 9                   Ixtapaluca         Edo. de México         nan
# 10             San Luis Potosí        San luis Potosí        0.00
# 11      San Pedro Garza García             Nuevo León         nan
# 12                   Querétaro              Querétaro        0.00
# 13               Benito Juárez       Distrito Federal       20.00
# 14                     Zapopan                Jalisco         nan
# 15         Naucalpan de Juárez         Edo. de México         nan
# 16                   Querétaro              Querétaro        0.00
# 17               Benito Juárez       Distrito Federal        5.00
# 18                   Querétaro              Querétaro         nan
# 19                   Querétaro              Querétaro        0.00
# 20                   Monterrey             Nuevo León        0.00
# 21                   Querétaro              Querétaro         nan
#         escuelascercanas  centroscomercialescercanos      precio
# 0                   0.00                        0.00  2273000.00
# 1                   1.00                        1.00  3600000.00
# 2                   0.00                        0.00  1200000.00
# 3                   1.00                        1.00   650000.00
# 4                   0.00                        0.00  1150000.00
# 5                   0.00                        1.00  1100000.00
# 6                   0.00                        0.00  1150000.00
# 7                   0.00                        0.00  4200000.00
# 8                   1.00                        1.00   310000.00
# 9                   0.00                        0.00  6200000.00
# 10                  1.00                        1.00   488000.00
# 11                  0.00                        0.00  7200000.00
# 12                  1.00                        1.00  1500000.00
# 13                  0.00                        0.00  3000000.00
# 14                  0.00                        0.00  5300000.00
# 15                  0.00                        0.00  3650000.00
# 16                  1.00                        1.00  2450000.00
# 17                  1.00                        1.00  4750000.00
# 18                  1.00                        1.00   794078.00
# 19                  0.00                        0.00  1850000.00
# 20                  0.00                        0.00   490000.00
# 21                  0.00                        0.00  2300000.00
# 22                  0.00                        0.00  1340000.00
# 23                  0.00                        0.00  3500000.00
# 24                  1.00                        1.00  3900000.00
# 25                  1.00                        1.00   850000.00
# 26                  1.00                        1.00   310000.00
# 27                  0.00                        0.00 10800000.00
# 28                  0.00                        0.00  2600000.00
# 29                  1.00                        0.00 10707900.00
# ...                  ...                         ...         ...
# 239970              0.00                        0.00  3350000.00
# 239971              1.00                        1.00  3750000.00
# 239972              1.00                        1.00  2400000.00
# 239973              1.00                        1.00  1260000.00
# 239974              0.00                        0.00  3300000.00
# 239975              1.00                        0.00  1275000.00
# 239976              0.00                        0.00  2020000.00
# 239977              0.00                        0.00   490000.00
# 239978              0.00                        0.00  1880000.00
# 239979              1.00                        1.00  3300000.00
# 239980              0.00                        0.00  3386400.00
# 239981              1.00                        1.00   550000.00
# 239982              0.00                        0.00   357000.00
# 239983              0.00                        0.00   684338.00
# 239984              1.00                        1.00   505000.00
# 239985              1.00                        1.00  2700000.00
# 239986              0.00                        0.00  2079000.00
# 239987              0.00                        0.00   830000.00
# 239988              0.00                        0.00  1990000.00
# 239989              1.00                        1.00  3850000.00
# 239990              0.00                        0.00  1495000.00
# 239991              1.00                        1.00  1450000.00
# 239992              1.00                        1.00  5500000.00
# 239993              0.00                        0.00  1650000.00
# 239994              0.00                        0.00  1350000.00
# 239995              0.00                        0.00   650000.00
# 239996              1.00                        1.00  1940000.00
# 239997              0.00                        0.00  3400000.00
# 239998              1.00                        1.00  2890000.00
# 239999              0.00                        0.00  3650000.00
#
# [240000 rows x 23 columns]>

# %% [markdown]
# ## ¿Cual es el periodo cubierto por las fechas?

# %%
print("Fecha Min.: ", train['fecha'].min())
print("Fecha Max.: ", train['fecha'].max())
# Out:
# Fecha Min.:  2012-01-01 00:00:00
# Fecha Max.:  2016-12-31 00:00:00

# %% [markdown]
# ## ¿Cómo se distribuyen las publicaciones de propiedades por año?

# %%
prop_total = train
ax = prop_total['fecha'].dt.year.value_counts().sort_index().plot.bar(title="propiedades por año")
ax.set_xlabel('año')
ax.set_ylabel('cantidad')
# Out:
# Text(0, 0.5, 'cantidad')

# %%
# Diferenciamos mes y año
prop = train
prop['year'] = train['fecha'].dt.year
prop['month'] = prop['fecha'].dt.month

# %%
prop_2012 = train[train['fecha'].dt.year == 2012]
prop_2013 = train[train['fecha'].dt.year == 2013]
prop_2014 = train[train['fecha'].dt.year == 2014]
prop_2015 = train[train['fecha'].dt.year == 2015]
prop_2016 = train[train['fecha'].dt.year == 2016]

# %%
# Removemos las publicaciones de diciembre por tenes en el último a año un valor muy elevado
prop2 = prop[(prop['year'] != 2016) & (prop['month'] != 12)]
prop2.groupby(by=['year','month']).count()['id'].unstack().transpose()\
.plot.bar(figsize=(20,10),title="Publicaciones por mes según año")

# %% [markdown]
# ## ¿Cualés son los diferentes tipos de propiedad y cómo se distribuyen sobre el total?

# %%
prop.groupby('tipodepropiedad').count()\
['id'].sort_values(ascending=False).plot.bar(title="Cantidades y tipos de propiedades")
# Se puede ver que la gran mayoría de publicaciones corresponde a propiedades del tipo 'Casa'

# %% [markdown]
# ## ¿Qué relación existe entre el precio, los metros cuadrados y la cantidad de habitaciones de los departamentos?

# %%
# Seteamos el precio en dolares
cotizacion_hoy = 19.54
prop['precio_USD'] = prop['precio'] / cotizacion_hoy

print(prop['precio_USD'].head(2))
print(prop['precio'].head(2))

prop['precioXmt'] = prop['precio_USD']/prop['metrostotales']
# Out:
# 0   116325.49
# 1   184237.46
# Name: precio_USD, dtype: float64
# 0   2273000.00
# 1   3600000.00
# Name: precio, dtype: float64

# %%
deptos = prop[prop['tipodepropiedad'] == 'Apartamento']
deptos[['antiguedad','precioXmt','metrostotales','precio_USD','habitaciones']].describe()
# Vemos que el 75% de los departamentos tiene hasta 3 habitaciones
# Out:
#        antiguedad  precioXmt  metrostotales  precio_USD  habitaciones
# count    48290.00   29348.00       29348.00    57341.00      56347.00
# mean         8.36    1163.48         117.91   141441.59          2.39
# std          9.52     746.75          67.70   119896.35          0.63
# min          0.00      44.78          15.00    15864.89          1.00
# 25%          1.00     660.49          70.00    53735.93          2.00
# 50%          5.00    1038.21          97.00   101807.98          2.00
# 75%         10.00    1516.36         145.00   190973.64          3.00
# max         80.00   37529.85         438.00   640736.95         10.00

# %%
(prop.groupby('habitaciones').count()['id'])/prop['habitaciones'].count()*100
# Out:
# habitaciones
# 1.00     2.33
# 2.00    26.57
# 3.00    56.03
# 4.00    11.52
# 5.00     2.11
# 6.00     0.77
# 7.00     0.25
# 8.00     0.18
# 9.00     0.08
# 10.00    0.15
# Name: id, dtype: float64

# %%
r = deptos[['precioXmt','metrostotales','habitaciones']]
# Sacamos los NaN
r = r[~r['metrostotales'].isna()]
# Sacamos los que tienen menos de max_hab habitaciones, ya que son casos aislados
max_hab = 5
r = r[r['habitaciones'] < max_hab]
r = r.sort_values(by=['metrostotales'],ascending=True)
r = r.plot.scatter(x='asdf',y='precioXmt',c='habitaciones',colormap='viridis',figsize=(15,8),s=1)
r.set_ylabel('precio por metro cuadrado',fontsize=12)
r.set_xlabel('metros totales',fontsize=12)
r.set_title('Distribución del precio por metro cuadrado según cantidad de habitaciones',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribución del precio por metro cuadrado según cantidad de habitaciones')

# %%
r = deptos[['precioXmt','metrostotales','habitaciones']]
# Sacamos los NaN
r = r[~r['metrostotales'].isna()]
# Sacamos los que tienen menos de max_hab habitaciones, ya que son casos aislados
max_hab = 5
r = r[r['habitaciones'] < max_hab]
r = r.sort_values(by=['metrostotales'],ascending=True)
r.head()
# Out:
#         precioXmt  metrostotales  habitaciones
# 153782   37529.85          15.00          3.00
# 223836    1493.69          15.00          2.00
# 129698    1595.39          15.00          2.00
# 59462    13476.63          15.00          3.00
# 197997   12838.35          16.00          2.00

# %% [markdown]
# ## ¿Cómo se distribuyen las publicaciones de deptos según los metros totales?

# %%
# Vamos a estudiar los departamentos
deptos = prop[prop['tipodepropiedad'] == 'Apartamento']
deptos['precioXmt'] = deptos['precio_USD'] / deptos['metrostotales']
# Out:
# /home/lucas/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
r = deptos[['precioXmt','metrostotales','precio_USD']]
limite1 = 30000
limite2 = 50000
limite3 = 100000
#Saco los NaN
r = r[~r['metrostotales'].isna()]
r2 = r[r['precio_USD'] < limite1]
r2.sort_values('metrostotales').plot.scatter(x='metrostotales',y='precio_USD',s=1,title='distribución metros x precio USD')

r3 = r[r['precio_USD'] < limite2]
r3.sort_values('metrostotales').plot.scatter(x='metrostotales',y='precio_USD',s=1,c='red',title='distribución metros x precio USD')

r4 = r[r['precio_USD'] < limite3]
r4.sort_values('metrostotales').plot.scatter(x='metrostotales',y='precio_USD',s=1,c='green',title='distribución metros x precio USD')

# %% [markdown]
# ## ¿Qué relación existe entre el precio y la cantidad de metros cuadrados de la propiedad?

# %%
prop.head(1).transpose()
# Out:
#                                                                             0
# id                                                                     254099
# titulo                                                      depto. tipo a-402
# descripcion                 depto. interior de 80.15m2, consta de sala com...
# tipodepropiedad                                                   Apartamento
# direccion                                     Avenida Division del Norte 2005
# ciudad                                                          Benito Juárez
# provincia                                                    Distrito Federal
# antiguedad                                                                NaN
# habitaciones                                                             2.00
# garages                                                                  1.00
# banos                                                                    2.00
# metroscubiertos                                                         80.00
# metrostotales                                                           80.00
# idzona                                                               23533.00
# lat                                                                       NaN
# lng                                                                       NaN
# fecha                                                     2015-08-23 00:00:00
# gimnasio                                                                 0.00
# usosmultiples                                                            0.00
# piscina                                                                  0.00
# escuelascercanas                                                         0.00
# centroscomercialescercanos                                               0.00
# precio                                                             2273000.00
# year                                                                     2015
# month                                                                       8
# precio_USD                                                          116325.49
# precioXmt                                                             1454.07

# %%
prop_sorted = prop[['precio_USD','metrostotales']].sort_values(by='metrostotales',ascending=True)

# %%
p = prop_sorted['metrostotales']
# En miles de dólares
m = (prop_sorted['precio_USD'] / 1000)
plt.plot(p,m)
plt.xlabel('metros totales')
plt.ylabel('precio USD en miles')
plt.title('Metros totales vs precio USD')
plt.figure(num=None,figsize=(10,10), dpi=80, facecolor='w', edgecolor='k')
#.set_size_inches(18.5, 10.5, forward=True)
#plt.show()
#fig.set_size_inches(18.5, 10.5)

# %%
prop_sorted_2 = prop_sorted[prop_sorted['precio_USD'] > 200000]
prop_sorted_2.head()
p2 = prop_sorted_2['metrostotales']
# En miles de dólares
m2 = (prop_sorted_2['precio_USD'] / 1000)
plt.plot(p2,m2)
plt.xlabel('metros totales')
plt.ylabel('precio USD en miles')
plt.title('Metros totales vs precio USD')
plt.figure(num=None,figsize=(20,20), dpi=80, facecolor='w', edgecolor='k')

# %% [markdown]
# ## ¿Cuál es el precio promedio por ciudad por año para las 10 ciudades de mayor precio historico?

# %%
prop.head(2).transpose()
# Out:
#                                                                        11188   \
# id                                                                     192202
# titulo                                                terreno antes de cholul
# descripcion                 <p>justo antes del pueblo de cholul, excelente...
# tipodepropiedad                                                       Terreno
# direccion                                                              merida
# ciudad                                                                  Abalá
# provincia                                                             Yucatán
# antiguedad                                                               0.00
# habitaciones                                                              NaN
# garages                                                                  0.00
# banos                                                                     NaN
# metroscubiertos                                                           NaN
# metrostotales                                                          200.00
# idzona                                                                    NaN
# lat                                                                       NaN
# lng                                                                       NaN
# fecha                                                     2013-09-22 00:00:00
# gimnasio                                                                 0.00
# usosmultiples                                                            0.00
# piscina                                                                  0.00
# escuelascercanas                                                         0.00
# centroscomercialescercanos                                               0.00
# precio                                                              315000.00
# year                                                                     2013
# month                                                                       9
# precio_USD                                                           16120.78
# precioXmt                                                               80.60
# count                                                                       1
#
#                                                                        138118
# id                                                                     284662
# titulo                                  casa uso de suelo en venta en abasolo
# descripcion                 id:22939, <p>planta baja.- area comercial, ofi...
# tipodepropiedad                                             Casa uso de suelo
# direccion                                                                 NaN
# ciudad                                                                Abasolo
# provincia                                                          Nuevo León
# antiguedad                                                                NaN
# habitaciones                                                             3.00
# garages                                                                  0.00
# banos                                                                    2.00
# metroscubiertos                                                        138.00
# metrostotales                                                           72.00
# idzona                                                                    NaN
# lat                                                                     25.65
# lng                                                                   -100.14
# fecha                                                     2016-04-24 00:00:00
# gimnasio                                                                 0.00
# usosmultiples                                                            0.00
# piscina                                                                  0.00
# escuelascercanas                                                         0.00
# centroscomercialescercanos                                               0.00
# precio                                                              680000.00
# year                                                                     2016
# month                                                                       4
# precio_USD                                                           34800.41
# precioXmt                                                              483.34
# count                                                                       1

# %%
prop[['ciudad','precio_USD']].describe()
# Out:
#        precio_USD
# count   240000.00
# mean    129520.90
# std     110161.30
# min      15864.89
# 25%      48760.11
# 50%      94677.58
# 75%     173490.28
# max     640992.84

# %%
prop_mean_year_city.head(5)
# Out:
#    year              ciudad  precio_USD_prom
# 0  2012             Acambay         23029.68
# 1  2012  Acapulco de Juárez        102178.87
# 2  2012             Acolman         35630.21
# 3  2012             Actopan        247239.00
# 4  2012              Aculco        281473.90

# %%
prop_mean_year_city_g = prop.groupby(['year','ciudad']).mean()['precio_USD']

# %%
prop_mean_year_city=prop_mean_year_city_g.reset_index().rename(columns={"precio_USD": "precio_USD_prom"})

# %%
ax = prop_mean_year_city[prop_mean_year_city['year'] == 2012][['ciudad','precio_USD_prom']]\
.sort_values(by='precio_USD_prom',ascending=True).head(10).plot.barh(x='ciudad',y='precio_USD_prom',figsize=(10,10))
ax.set_xlabel('precio USD promedio',fontsize=12)
ax.set_ylabel('ciudad',fontsize=12)
ax.set_title('Precio usd promedio por ciudad',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Precio usd promedio por ciudad')

# %%
#Para exportar la imagen generada en el plot
#fig = ax.get_figure()
#fig.savefig('/tmp/img_export.png')

# %%
precio_mean_2012 = prop_mean_year_city[prop_mean_year_city['year']==2012].sort_values(by='precio_USD_prom',ascending=False)[['ciudad','precio_USD_prom']]
precio_mean_2013 = prop_mean_year_city[prop_mean_year_city['year']==2013].sort_values(by='precio_USD_prom',ascending=False)[['ciudad','precio_USD_prom']]
precio_mean_2014 = prop_mean_year_city[prop_mean_year_city['year']==2014].sort_values(by='precio_USD_prom',ascending=False)[['ciudad','precio_USD_prom']]
precio_mean_2015 = prop_mean_year_city[prop_mean_year_city['year']==2015].sort_values(by='precio_USD_prom',ascending=False)[['ciudad','precio_USD_prom']]
precio_mean_2016 = prop_mean_year_city[prop_mean_year_city['year']==2016].sort_values(by='precio_USD_prom',ascending=False)[['ciudad','precio_USD_prom']]

# %%
precio_m_anios = pd.DataFrame()
precio_m_anios[['ciudad','p_m_2012']] = precio_mean_2012[['ciudad','precio_USD_prom']]
precio_m_anios = precio_m_anios.set_index('ciudad')

# %%
precio_m_anios=precio_m_anios.join(precio_mean_2013.set_index('ciudad')).rename(columns={"precio_USD_prom":"p_m_2013"})
precio_m_anios=precio_m_anios.join(precio_mean_2014.set_index('ciudad')).rename(columns={"precio_USD_prom":"p_m_2014"})
precio_m_anios=precio_m_anios.join(precio_mean_2015.set_index('ciudad')).rename(columns={"precio_USD_prom":"p_m_2015"})
precio_m_anios=precio_m_anios.join(precio_mean_2016.set_index('ciudad')).rename(columns={"precio_USD_prom":"p_m_2016"})
precio_m_anios.head(10)
# Out:
#                      p_m_2012  p_m_2013  p_m_2014  p_m_2015  p_m_2016
# ciudad
# Batopilas           614124.87       nan       nan       nan       nan
# Hunucmá             460593.65       nan  44012.28       nan  46059.37
# Tenancingo          460593.65 166325.49 122824.97 198311.16 106517.40
# Villa Victoria      450358.24       nan       nan 127942.68 193193.45
# Tolimán             383828.05       nan       nan  51177.07 179119.75
# PuruAndiro          332650.97       nan       nan       nan       nan
# San Pablo del Monte 332650.97       nan       nan       nan       nan
# Chignahuapan        332650.97       nan  29682.70       nan       nan
# Moroleón            317297.85       nan       nan  16064.48  79665.64
# otra                304503.58 133856.48 242425.79 193643.81 101864.25

# %%
import matplotlib as mpl
#cmap = mpl.cm.cool
plot = precio_m_anios.head(10).plot.bar(figsize=(10,9),cmap='viridis')#'viridis',RdPu
plot.set_xlabel('Ciudad',fontsize=12)
plot.set_ylabel('precio promedio USD',fontsize=12)
plot.set_title('Precio promedio USD vs Ciudad para las 10 ciudades con max historico',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Precio promedio USD vs Ciudad para las 10 ciudades con max historico')

# %% [markdown]
# ## ¿Cómo se distribuyen las cantidades de publicaciones según la antiguedad en distintas ciudades?

# %%
prop.head(2)
# Out:
#             id                                 titulo  \
# 11188   192202                terreno antes de cholul
# 138118  284662  casa uso de suelo en venta en abasolo
#
#                                               descripcion    tipodepropiedad  \
# 11188   <p>justo antes del pueblo de cholul, excelente...            Terreno
# 138118  id:22939, <p>planta baja.- area comercial, ofi...  Casa uso de suelo
#
#        direccion   ciudad   provincia  antiguedad  habitaciones  garages  \
# 11188     merida    Abalá     Yucatán        0.00           nan     0.00
# 138118       NaN  Abasolo  Nuevo León         nan          3.00     0.00
#
#         banos  metroscubiertos  metrostotales  idzona   lat     lng  \
# 11188     nan              nan         200.00     nan   nan     nan
# 138118   2.00           138.00          72.00     nan 25.65 -100.14
#
#             fecha  gimnasio  usosmultiples  piscina  escuelascercanas  \
# 11188  2013-09-22      0.00           0.00     0.00              0.00
# 138118 2016-04-24      0.00           0.00     0.00              0.00
#
#         centroscomercialescercanos    precio  year  month  precio_USD  \
# 11188                         0.00 315000.00  2013      9    16120.78
# 138118                        0.00 680000.00  2016      4    34800.41
#
#         precioXmt  count
# 11188       80.60      1
# 138118     483.34      1

# %%
prop[prop['ciudad'] == 'Abasolo'][['antiguedad','year']]
# Out:
#         antiguedad  year
# 138118         nan  2016
# 30789          nan  2016
# 52476          nan  2015
# 13057        15.00  2013
# 152020        5.00  2014
# 117413       20.00  2016

# %%
labCyA = ['ciudad','antiguedad']
ciudades_ant = prop.groupby(by=labCyA).count()\
.reset_index()[labCyA].groupby(by='antiguedad').count()\
.sort_values('ciudad',ascending=False).reset_index()['ciudad']

# %%
plot = ciudades_ant.plot(kind='bar',figsize=(15,10))
plot.set_xlabel('Años de antiguedad',fontsize=12)
plot.set_ylabel('Cantidad de ciudades con publicaciones',fontsize=12)
plot.set_title('Cantidad de ciudades con publicaciones por antiguedad de propiedad',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Cantidad de ciudades con publicaciones por antiguedad de propiedad')

# %%
#Se puede ver que existe una gran cantidad de ciudades distintas con departamentos nuevos, pero
#esa tendencia va disminuyendo a medida que aumenta la antiguedad.

# %% [markdown]
# ## ¿Cuál es la antiguedad promedio según la ciudad?

# %%
prop_ant_mean = prop
prop_ant_mean['count'] = 1
prop_ant_mean = prop_ant_mean[['ciudad','antiguedad','count']]
prop_ant_mean.sort_values(by='ciudad',inplace=True)
pam = prop_ant_mean.groupby(by=['ciudad']).sum().reset_index()
pam['mean'] = pam.apply(lambda x: x[1]/x[2],axis=1)
pam = pam.rename(columns={'antiguedad':'antiguedad_total','mean':'mean_antiguedad'})
# Out:
# /home/lucas/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
pam = pam.sort_values(by='mean_antiguedad')
pam.tail()
# Out:
#          ciudad  antiguedad_total  count  mean_antiguedad
# 502      Poanas             35.00      1            35.00
# 7       Acateno             35.00      1            35.00
# 710  Tepetitlán            181.00      5            36.20
# 14     Acuitzio             50.00      1            50.00
# 17   Agua Dulce             80.00      1            80.00

# %%
#pam['mean_antiguedad'].plot(kind='bar',legend=False,width=0.5,figsize=(20,10),cmap='Reds')
pam[['mean_antiguedad','ciudad']].set_index('ciudad').plot(figsize=(20,10),title='Antiguedad promedio por ciudad')

# %%
pam[['mean_antiguedad','ciudad']].sort_values(by='mean_antiguedad').set_index('ciudad').plot(figsize=(20,10),title='Antiguedad promedio por ciudad')

# %%
pam[['mean_antiguedad','ciudad']].sort_values(by='mean_antiguedad').reset_index()[['mean_antiguedad','ciudad']]\
.plot(figsize=(20,10),title='Antiguedad promedio por ciudad')

# %%
pam['ciudad'].count()
# Out:
# 875
